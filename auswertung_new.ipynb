# %% [markdown]
# # Auswertung der Ergebnisse
# Dieses Notebook liest die Ergebnisse aus den JSON-Dateien im Ordner `results` aus und stellt sie in einer übersichtlichen Tabelle dar.

# %%
import os
import json
import pandas as pd
from IPython.display import display
import itertools

pd.set_option('display.max_rows', None)

results_dir = 'results/all-2025-08-08_16:13:57'
data = []

for dataset_folder in os.listdir(results_dir):
    dataset_path = os.path.join(results_dir, dataset_folder)
    if os.path.isdir(dataset_path):
        for filename in os.listdir(dataset_path):
            if filename.endswith('.json'):
                filepath = os.path.join(dataset_path, filename)
                with open(filepath, 'r') as f:
                    content = json.load(f)
                    
                training_method = content.get('training_method', 'N/A')
                testing_method = content.get('testing_method', 'N/A')
                is_filtered_file = '_filter' in filename
                
                for result in content.get('anonymization_results', []):
                    anonymization_level = result.get('level', 'N/A')
                    
                    if is_filtered_file and result.get('filtering', {}).get('enabled') and result.get('filtering', {}).get('results'):
                        for filter_result in result['filtering']['results']:
                            data.append({
                                'Dataset': dataset_folder,
                                'Training Method': training_method,
                                'Testing Method': testing_method,
                                'Anonymization Level': anonymization_level,
                                'F1 Score (avg)': filter_result.get('metrics', {}).get('f1_score_avg', 0),
                                'Filtered': 'Yes',
                                'Filter Mode': filter_result.get('mode', 'N/A'),
                                'n_duplicates': filter_result.get('n_duplicates', 'N/A')
                            })
                    else:
                        # This handles both non-filtered files and non-filtered results within filtered files
                        if result.get('metrics', {}).get('f1_score_avg') is not None:
                            data.append({
                                'Dataset': dataset_folder,
                                'Training Method': training_method,
                                'Testing Method': testing_method,
                                'Anonymization Level': anonymization_level,
                                'F1 Score (avg)': result.get('metrics', {}).get('f1_score_avg', 0),
                                'Filtered': 'No',
                                'Filter Mode': 'N/A',
                                'n_duplicates': 'N/A'
                            })

df = pd.DataFrame(data)
df['F1 Score (avg)'] = (df['F1 Score (avg)'] * 100).round(1)

# --- Add missing rows ---
training_method_order = ['original', 'no_preprocessing', 'forced_generalization', 'weighted_specialization']
testing_method_order = ['original', 'no_preprocessing', 'forced_generalization', 'weighted_specialization']
anonymization_level_order = ['no', 'basic', 'all']
datasets = df['Dataset'].unique()

filter_configs = []
filter_configs.append({'Filtered': 'No', 'Filter Mode': 'N/A', 'n_duplicates': 'N/A'})
filter_modes = ['unique', 'random', 'imputation', 'knn', 'autoencoder']
for mode in filter_modes:
    if mode == 'unique':
        filter_configs.append({'Filtered': 'Yes', 'Filter Mode': mode, 'n_duplicates': 0})
    else:
        for n_dup in [1, 3, 5]:
            filter_configs.append({'Filtered': 'Yes', 'Filter Mode': mode, 'n_duplicates': n_dup})

all_combinations = list(itertools.product(datasets, training_method_order, testing_method_order, anonymization_level_order))

expected_df = []
for d, tr, te, al in all_combinations:
    if tr == 'weighted_specialization':
        if al == 'no':
            # For 'no' anon level, expect non-filtered and one specific filtered result
            expected_df.append({
                'Dataset': d, 'Training Method': tr, 'Testing Method': te, 'Anonymization Level': al,
                'Filtered': 'No', 'Filter Mode': 'N/A', 'n_duplicates': 'N/A'
            })
            expected_df.append({
                'Dataset': d, 'Training Method': tr, 'Testing Method': te, 'Anonymization Level': al,
                'Filtered': 'Yes', 'Filter Mode': 'unique', 'n_duplicates': 0
            })
        else:
            # For 'basic' or 'all' anon, expect all filter configurations
            for fc in filter_configs:
                expected_df.append({
                    'Dataset': d, 'Training Method': tr, 'Testing Method': te, 'Anonymization Level': al,
                    'Filtered': fc['Filtered'], 'Filter Mode': fc['Filter Mode'], 'n_duplicates': fc['n_duplicates']
                })
    else:
        # For other training methods, only expect non-filtered results
        fc = filter_configs[0]
        expected_df.append({
            'Dataset': d, 'Training Method': tr, 'Testing Method': te, 'Anonymization Level': al,
            'Filtered': fc['Filtered'], 'Filter Mode': fc['Filter Mode'], 'n_duplicates': fc['n_duplicates']
        })

expected_df = pd.DataFrame(expected_df)

merged_df = pd.merge(expected_df, df, on=list(expected_df.columns), how='left')
merged_df['F1 Score (avg)'] = merged_df['F1 Score (avg)'].fillna('TODO')

df = merged_df

# Define custom sort order
df['Training Method'] = pd.Categorical(df['Training Method'], categories=training_method_order, ordered=True)
df['Testing Method'] = pd.Categorical(df['Testing Method'], categories=testing_method_order, ordered=True)
df['Anonymization Level'] = pd.Categorical(df['Anonymization Level'], categories=anonymization_level_order, ordered=True)

df = df.sort_values(by=['Dataset', 'Testing Method', 'Training Method', 'Anonymization Level', 'Filtered', 'Filter Mode', 'n_duplicates'])

# %%
print("Adult Dataset F1-Scores")
display(df[df["Dataset"]=="adult"].drop("Dataset", axis=1))
# Out:
# Adult Dataset F1-Scores
#              Training Method           Testing Method Anonymization Level  \
# 165                 original                 original                  no
# 166                 original                 original               basic
# 167                 original                 original                 all
# 179         no_preprocessing                 original                  no
# 180         no_preprocessing                 original               basic
# 181         no_preprocessing                 original                 all
# 193    forced_generalization                 original                  no
# 194    forced_generalization                 original               basic
# 195    forced_generalization                 original                 all
# 207  weighted_specialization                 original                  no
# 208  weighted_specialization                 original                  no
# 209  weighted_specialization                 original               basic
# 220  weighted_specialization                 original               basic
# 221  weighted_specialization                 original               basic
# 222  weighted_specialization                 original               basic
# 214  weighted_specialization                 original               basic
# 215  weighted_specialization                 original               basic
# 216  weighted_specialization                 original               basic
# 217  weighted_specialization                 original               basic
# 218  weighted_specialization                 original               basic
# 219  weighted_specialization                 original               basic
# 211  weighted_specialization                 original               basic
# 212  weighted_specialization                 original               basic
# 213  weighted_specialization                 original               basic
# 210  weighted_specialization                 original               basic
# 223  weighted_specialization                 original                 all
# 234  weighted_specialization                 original                 all
# 235  weighted_specialization                 original                 all
# 236  weighted_specialization                 original                 all
# 228  weighted_specialization                 original                 all
# 229  weighted_specialization                 original                 all
# 230  weighted_specialization                 original                 all
# 231  weighted_specialization                 original                 all
# 232  weighted_specialization                 original                 all
# 233  weighted_specialization                 original                 all
# 225  weighted_specialization                 original                 all
# 226  weighted_specialization                 original                 all
# 227  weighted_specialization                 original                 all
# 224  weighted_specialization                 original                 all
# 168                 original         no_preprocessing                  no
# 169                 original         no_preprocessing               basic
# 170                 original         no_preprocessing                 all
# 182         no_preprocessing         no_preprocessing                  no
# 183         no_preprocessing         no_preprocessing               basic
# 184         no_preprocessing         no_preprocessing                 all
# 196    forced_generalization         no_preprocessing                  no
# 197    forced_generalization         no_preprocessing               basic
# 198    forced_generalization         no_preprocessing                 all
# 237  weighted_specialization         no_preprocessing                  no
# 238  weighted_specialization         no_preprocessing                  no
# 239  weighted_specialization         no_preprocessing               basic
# 250  weighted_specialization         no_preprocessing               basic
# 251  weighted_specialization         no_preprocessing               basic
# 252  weighted_specialization         no_preprocessing               basic
# 244  weighted_specialization         no_preprocessing               basic
# 245  weighted_specialization         no_preprocessing               basic
# 246  weighted_specialization         no_preprocessing               basic
# 247  weighted_specialization         no_preprocessing               basic
# 248  weighted_specialization         no_preprocessing               basic
# 249  weighted_specialization         no_preprocessing               basic
# 241  weighted_specialization         no_preprocessing               basic
# 242  weighted_specialization         no_preprocessing               basic
# 243  weighted_specialization         no_preprocessing               basic
# 240  weighted_specialization         no_preprocessing               basic
# 253  weighted_specialization         no_preprocessing                 all
# 264  weighted_specialization         no_preprocessing                 all
# 265  weighted_specialization         no_preprocessing                 all
# 266  weighted_specialization         no_preprocessing                 all
# 258  weighted_specialization         no_preprocessing                 all
# 259  weighted_specialization         no_preprocessing                 all
# 260  weighted_specialization         no_preprocessing                 all
# 261  weighted_specialization         no_preprocessing                 all
# 262  weighted_specialization         no_preprocessing                 all
# 263  weighted_specialization         no_preprocessing                 all
# 255  weighted_specialization         no_preprocessing                 all
# 256  weighted_specialization         no_preprocessing                 all
# 257  weighted_specialization         no_preprocessing                 all
# 254  weighted_specialization         no_preprocessing                 all
# 171                 original    forced_generalization                  no
# 172                 original    forced_generalization               basic
# 173                 original    forced_generalization                 all
# 185         no_preprocessing    forced_generalization                  no
# 186         no_preprocessing    forced_generalization               basic
# 187         no_preprocessing    forced_generalization                 all
# 199    forced_generalization    forced_generalization                  no
# 200    forced_generalization    forced_generalization               basic
# 201    forced_generalization    forced_generalization                 all
# 267  weighted_specialization    forced_generalization                  no
# 268  weighted_specialization    forced_generalization                  no
# 269  weighted_specialization    forced_generalization               basic
# 280  weighted_specialization    forced_generalization               basic
# 281  weighted_specialization    forced_generalization               basic
# 282  weighted_specialization    forced_generalization               basic
# 274  weighted_specialization    forced_generalization               basic
# 275  weighted_specialization    forced_generalization               basic
# 276  weighted_specialization    forced_generalization               basic
# 277  weighted_specialization    forced_generalization               basic
# 278  weighted_specialization    forced_generalization               basic
# 279  weighted_specialization    forced_generalization               basic
# 271  weighted_specialization    forced_generalization               basic
# 272  weighted_specialization    forced_generalization               basic
# 273  weighted_specialization    forced_generalization               basic
# 270  weighted_specialization    forced_generalization               basic
# 283  weighted_specialization    forced_generalization                 all
# 294  weighted_specialization    forced_generalization                 all
# 295  weighted_specialization    forced_generalization                 all
# 296  weighted_specialization    forced_generalization                 all
# 288  weighted_specialization    forced_generalization                 all
# 289  weighted_specialization    forced_generalization                 all
# 290  weighted_specialization    forced_generalization                 all
# 291  weighted_specialization    forced_generalization                 all
# 292  weighted_specialization    forced_generalization                 all
# 293  weighted_specialization    forced_generalization                 all
# 285  weighted_specialization    forced_generalization                 all
# 286  weighted_specialization    forced_generalization                 all
# 287  weighted_specialization    forced_generalization                 all
# 284  weighted_specialization    forced_generalization                 all
# 174                 original  weighted_specialization                  no
# 175                 original  weighted_specialization                  no
# 176                 original  weighted_specialization               basic
# 177                 original  weighted_specialization               basic
# 178                 original  weighted_specialization                 all
# 188         no_preprocessing  weighted_specialization                  no
# 189         no_preprocessing  weighted_specialization                  no
# 190         no_preprocessing  weighted_specialization               basic
# 191         no_preprocessing  weighted_specialization               basic
# 192         no_preprocessing  weighted_specialization                 all
# 202    forced_generalization  weighted_specialization                  no
# 203    forced_generalization  weighted_specialization                  no
# 204    forced_generalization  weighted_specialization               basic
# 205    forced_generalization  weighted_specialization               basic
# 206    forced_generalization  weighted_specialization                 all
# 297  weighted_specialization  weighted_specialization                  no
# 298  weighted_specialization  weighted_specialization                  no
# 299  weighted_specialization  weighted_specialization               basic
# 310  weighted_specialization  weighted_specialization               basic
# 311  weighted_specialization  weighted_specialization               basic
# 312  weighted_specialization  weighted_specialization               basic
# 304  weighted_specialization  weighted_specialization               basic
# 305  weighted_specialization  weighted_specialization               basic
# 306  weighted_specialization  weighted_specialization               basic
# 307  weighted_specialization  weighted_specialization               basic
# 308  weighted_specialization  weighted_specialization               basic
# 309  weighted_specialization  weighted_specialization               basic
# 301  weighted_specialization  weighted_specialization               basic
# 302  weighted_specialization  weighted_specialization               basic
# 303  weighted_specialization  weighted_specialization               basic
# 300  weighted_specialization  weighted_specialization               basic
# 313  weighted_specialization  weighted_specialization                 all
# 324  weighted_specialization  weighted_specialization                 all
# 325  weighted_specialization  weighted_specialization                 all
# 326  weighted_specialization  weighted_specialization                 all
# 318  weighted_specialization  weighted_specialization                 all
# 319  weighted_specialization  weighted_specialization                 all
# 320  weighted_specialization  weighted_specialization                 all
# 321  weighted_specialization  weighted_specialization                 all
# 322  weighted_specialization  weighted_specialization                 all
# 323  weighted_specialization  weighted_specialization                 all
# 315  weighted_specialization  weighted_specialization                 all
# 316  weighted_specialization  weighted_specialization                 all
# 317  weighted_specialization  weighted_specialization                 all
# 314  weighted_specialization  weighted_specialization                 all
#
#     Filtered  Filter Mode n_duplicates F1 Score (avg)
# 165       No          N/A          N/A           81.3
# 166       No          N/A          N/A           81.3
# 167       No          N/A          N/A           81.3
# 179       No          N/A          N/A           80.9
# 180       No          N/A          N/A           78.7
# 181       No          N/A          N/A           48.0
# 193       No          N/A          N/A           81.1
# 194       No          N/A          N/A           80.4
# 195       No          N/A          N/A           58.2
# 207       No          N/A          N/A           81.1
# 208      Yes       unique            0           81.6
# 209       No          N/A          N/A           81.0
# 220      Yes  autoencoder            1           81.0
# 221      Yes  autoencoder            3           81.3
# 222      Yes  autoencoder            5           81.3
# 214      Yes   imputation            1           80.8
# 215      Yes   imputation            3           81.2
# 216      Yes   imputation            5           81.1
# 217      Yes          knn            1           80.9
# 218      Yes          knn            3           81.0
# 219      Yes          knn            5           81.1
# 211      Yes       random            1           80.8
# 212      Yes       random            3           81.0
# 213      Yes       random            5           81.1
# 210      Yes       unique            0           79.3
# 223       No          N/A          N/A           TODO
# 234      Yes  autoencoder            1           TODO
# 235      Yes  autoencoder            3           TODO
# 236      Yes  autoencoder            5           TODO
# 228      Yes   imputation            1           TODO
# 229      Yes   imputation            3           TODO
# 230      Yes   imputation            5           TODO
# 231      Yes          knn            1           TODO
# 232      Yes          knn            3           TODO
# 233      Yes          knn            5           TODO
# 225      Yes       random            1           TODO
# 226      Yes       random            3           TODO
# 227      Yes       random            5           TODO
# 224      Yes       unique            0           TODO
# 168       No          N/A          N/A           81.1
# 169       No          N/A          N/A           78.2
# 170       No          N/A          N/A           42.1
# 182       No          N/A          N/A           80.9
# 183       No          N/A          N/A           80.5
# 184       No          N/A          N/A           70.8
# 196       No          N/A          N/A           81.1
# 197       No          N/A          N/A           80.8
# 198       No          N/A          N/A           53.0
# 237       No          N/A          N/A           80.9
# 238      Yes       unique            0           81.4
# 239       No          N/A          N/A           78.1
# 250      Yes  autoencoder            1           TODO
# 251      Yes  autoencoder            3           TODO
# 252      Yes  autoencoder            5           TODO
# 244      Yes   imputation            1           TODO
# 245      Yes   imputation            3           TODO
# 246      Yes   imputation            5           TODO
# 247      Yes          knn            1           TODO
# 248      Yes          knn            3           TODO
# 249      Yes          knn            5           TODO
# 241      Yes       random            1           TODO
# 242      Yes       random            3           TODO
# 243      Yes       random            5           TODO
# 240      Yes       unique            0           TODO
# 253       No          N/A          N/A           TODO
# 264      Yes  autoencoder            1           TODO
# 265      Yes  autoencoder            3           TODO
# 266      Yes  autoencoder            5           TODO
# 258      Yes   imputation            1           TODO
# 259      Yes   imputation            3           TODO
# 260      Yes   imputation            5           TODO
# 261      Yes          knn            1           TODO
# 262      Yes          knn            3           TODO
# 263      Yes          knn            5           TODO
# 255      Yes       random            1           TODO
# 256      Yes       random            3           TODO
# 257      Yes       random            5           TODO
# 254      Yes       unique            0           TODO
# 171       No          N/A          N/A           81.1
# 172       No          N/A          N/A           77.6
# 173       No          N/A          N/A           22.9
# 185       No          N/A          N/A           81.1
# 186       No          N/A          N/A           80.4
# 187       No          N/A          N/A           68.2
# 199       No          N/A          N/A           80.9
# 200       No          N/A          N/A           80.9
# 201       No          N/A          N/A           69.3
# 267       No          N/A          N/A           81.3
# 268      Yes       unique            0           80.8
# 269       No          N/A          N/A           77.1
# 280      Yes  autoencoder            1           TODO
# 281      Yes  autoencoder            3           TODO
# 282      Yes  autoencoder            5           TODO
# 274      Yes   imputation            1           TODO
# 275      Yes   imputation            3           TODO
# 276      Yes   imputation            5           TODO
# 277      Yes          knn            1           TODO
# 278      Yes          knn            3           TODO
# 279      Yes          knn            5           TODO
# 271      Yes       random            1           TODO
# 272      Yes       random            3           TODO
# 273      Yes       random            5           TODO
# 270      Yes       unique            0           TODO
# 283       No          N/A          N/A           TODO
# 294      Yes  autoencoder            1           TODO
# 295      Yes  autoencoder            3           TODO
# 296      Yes  autoencoder            5           TODO
# 288      Yes   imputation            1           TODO
# 289      Yes   imputation            3           TODO
# 290      Yes   imputation            5           TODO
# 291      Yes          knn            1           TODO
# 292      Yes          knn            3           TODO
# 293      Yes          knn            5           TODO
# 285      Yes       random            1           TODO
# 286      Yes       random            3           TODO
# 287      Yes       random            5           TODO
# 284      Yes       unique            0           TODO
# 174       No          N/A          N/A           81.3
# 175       No          N/A          N/A           81.3
# 176       No          N/A          N/A           80.8
# 177       No          N/A          N/A           80.9
# 178       No          N/A          N/A           TODO
# 188       No          N/A          N/A           80.9
# 189       No          N/A          N/A           81.2
# 190       No          N/A          N/A           74.8
# 191       No          N/A          N/A           78.0
# 192       No          N/A          N/A           TODO
# 202       No          N/A          N/A           80.9
# 203       No          N/A          N/A           81.1
# 204       No          N/A          N/A           79.7
# 205       No          N/A          N/A           80.2
# 206       No          N/A          N/A           TODO
# 297       No          N/A          N/A           81.3
# 298      Yes       unique            0           81.3
# 299       No          N/A          N/A           80.9
# 310      Yes  autoencoder            1           80.9
# 311      Yes  autoencoder            3           81.0
# 312      Yes  autoencoder            5           80.7
# 304      Yes   imputation            1           80.9
# 305      Yes   imputation            3           80.7
# 306      Yes   imputation            5           81.1
# 307      Yes          knn            1           79.6
# 308      Yes          knn            3           80.8
# 309      Yes          knn            5           80.8
# 301      Yes       random            1           80.9
# 302      Yes       random            3           81.0
# 303      Yes       random            5           80.7
# 300      Yes       unique            0           76.5
# 313       No          N/A          N/A           TODO
# 324      Yes  autoencoder            1           TODO
# 325      Yes  autoencoder            3           TODO
# 326      Yes  autoencoder            5           TODO
# 318      Yes   imputation            1           TODO
# 319      Yes   imputation            3           TODO
# 320      Yes   imputation            5           TODO
# 321      Yes          knn            1           TODO
# 322      Yes          knn            3           TODO
# 323      Yes          knn            5           TODO
# 315      Yes       random            1           TODO
# 316      Yes       random            3           TODO
# 317      Yes       random            5           TODO
# 314      Yes       unique            0           TODO

# %%
print("\nDiabetes Dataset F1-Scores")
display(df[df["Dataset"]=="diabetes"].drop("Dataset", axis=1))
# Out:
# Diabetes Dataset F1-Scores
#              Training Method           Testing Method Anonymization Level  \
# 0                   original                 original                  no
# 1                   original                 original               basic
# 2                   original                 original                 all
# 15          no_preprocessing                 original                  no
# 16          no_preprocessing                 original               basic
# 17          no_preprocessing                 original                 all
# 30     forced_generalization                 original                  no
# 31     forced_generalization                 original               basic
# 32     forced_generalization                 original                 all
# 45   weighted_specialization                 original                  no
# 46   weighted_specialization                 original                  no
# 47   weighted_specialization                 original               basic
# 58   weighted_specialization                 original               basic
# 59   weighted_specialization                 original               basic
# 60   weighted_specialization                 original               basic
# 52   weighted_specialization                 original               basic
# 53   weighted_specialization                 original               basic
# 54   weighted_specialization                 original               basic
# 55   weighted_specialization                 original               basic
# 56   weighted_specialization                 original               basic
# 57   weighted_specialization                 original               basic
# 49   weighted_specialization                 original               basic
# 50   weighted_specialization                 original               basic
# 51   weighted_specialization                 original               basic
# 48   weighted_specialization                 original               basic
# 61   weighted_specialization                 original                 all
# 72   weighted_specialization                 original                 all
# 73   weighted_specialization                 original                 all
# 74   weighted_specialization                 original                 all
# 66   weighted_specialization                 original                 all
# 67   weighted_specialization                 original                 all
# 68   weighted_specialization                 original                 all
# 69   weighted_specialization                 original                 all
# 70   weighted_specialization                 original                 all
# 71   weighted_specialization                 original                 all
# 63   weighted_specialization                 original                 all
# 64   weighted_specialization                 original                 all
# 65   weighted_specialization                 original                 all
# 62   weighted_specialization                 original                 all
# 3                   original         no_preprocessing                  no
# 4                   original         no_preprocessing               basic
# 5                   original         no_preprocessing                 all
# 18          no_preprocessing         no_preprocessing                  no
# 19          no_preprocessing         no_preprocessing               basic
# 20          no_preprocessing         no_preprocessing                 all
# 33     forced_generalization         no_preprocessing                  no
# 34     forced_generalization         no_preprocessing               basic
# 35     forced_generalization         no_preprocessing                 all
# 75   weighted_specialization         no_preprocessing                  no
# 76   weighted_specialization         no_preprocessing                  no
# 77   weighted_specialization         no_preprocessing               basic
# 88   weighted_specialization         no_preprocessing               basic
# 89   weighted_specialization         no_preprocessing               basic
# 90   weighted_specialization         no_preprocessing               basic
# 82   weighted_specialization         no_preprocessing               basic
# 83   weighted_specialization         no_preprocessing               basic
# 84   weighted_specialization         no_preprocessing               basic
# 85   weighted_specialization         no_preprocessing               basic
# 86   weighted_specialization         no_preprocessing               basic
# 87   weighted_specialization         no_preprocessing               basic
# 79   weighted_specialization         no_preprocessing               basic
# 80   weighted_specialization         no_preprocessing               basic
# 81   weighted_specialization         no_preprocessing               basic
# 78   weighted_specialization         no_preprocessing               basic
# 91   weighted_specialization         no_preprocessing                 all
# 102  weighted_specialization         no_preprocessing                 all
# 103  weighted_specialization         no_preprocessing                 all
# 104  weighted_specialization         no_preprocessing                 all
# 96   weighted_specialization         no_preprocessing                 all
# 97   weighted_specialization         no_preprocessing                 all
# 98   weighted_specialization         no_preprocessing                 all
# 99   weighted_specialization         no_preprocessing                 all
# 100  weighted_specialization         no_preprocessing                 all
# 101  weighted_specialization         no_preprocessing                 all
# 93   weighted_specialization         no_preprocessing                 all
# 94   weighted_specialization         no_preprocessing                 all
# 95   weighted_specialization         no_preprocessing                 all
# 92   weighted_specialization         no_preprocessing                 all
# 6                   original    forced_generalization                  no
# 7                   original    forced_generalization               basic
# 8                   original    forced_generalization                 all
# 21          no_preprocessing    forced_generalization                  no
# 22          no_preprocessing    forced_generalization               basic
# 23          no_preprocessing    forced_generalization                 all
# 36     forced_generalization    forced_generalization                  no
# 37     forced_generalization    forced_generalization               basic
# 38     forced_generalization    forced_generalization                 all
# 105  weighted_specialization    forced_generalization                  no
# 106  weighted_specialization    forced_generalization                  no
# 107  weighted_specialization    forced_generalization               basic
# 118  weighted_specialization    forced_generalization               basic
# 119  weighted_specialization    forced_generalization               basic
# 120  weighted_specialization    forced_generalization               basic
# 112  weighted_specialization    forced_generalization               basic
# 113  weighted_specialization    forced_generalization               basic
# 114  weighted_specialization    forced_generalization               basic
# 115  weighted_specialization    forced_generalization               basic
# 116  weighted_specialization    forced_generalization               basic
# 117  weighted_specialization    forced_generalization               basic
# 109  weighted_specialization    forced_generalization               basic
# 110  weighted_specialization    forced_generalization               basic
# 111  weighted_specialization    forced_generalization               basic
# 108  weighted_specialization    forced_generalization               basic
# 121  weighted_specialization    forced_generalization                 all
# 132  weighted_specialization    forced_generalization                 all
# 133  weighted_specialization    forced_generalization                 all
# 134  weighted_specialization    forced_generalization                 all
# 126  weighted_specialization    forced_generalization                 all
# 127  weighted_specialization    forced_generalization                 all
# 128  weighted_specialization    forced_generalization                 all
# 129  weighted_specialization    forced_generalization                 all
# 130  weighted_specialization    forced_generalization                 all
# 131  weighted_specialization    forced_generalization                 all
# 123  weighted_specialization    forced_generalization                 all
# 124  weighted_specialization    forced_generalization                 all
# 125  weighted_specialization    forced_generalization                 all
# 122  weighted_specialization    forced_generalization                 all
# 9                   original  weighted_specialization                  no
# 10                  original  weighted_specialization                  no
# 11                  original  weighted_specialization               basic
# 12                  original  weighted_specialization               basic
# 13                  original  weighted_specialization                 all
# 14                  original  weighted_specialization                 all
# 24          no_preprocessing  weighted_specialization                  no
# 25          no_preprocessing  weighted_specialization                  no
# 26          no_preprocessing  weighted_specialization               basic
# 27          no_preprocessing  weighted_specialization               basic
# 28          no_preprocessing  weighted_specialization                 all
# 29          no_preprocessing  weighted_specialization                 all
# 39     forced_generalization  weighted_specialization                  no
# 40     forced_generalization  weighted_specialization                  no
# 41     forced_generalization  weighted_specialization               basic
# 42     forced_generalization  weighted_specialization               basic
# 43     forced_generalization  weighted_specialization                 all
# 44     forced_generalization  weighted_specialization                 all
# 135  weighted_specialization  weighted_specialization                  no
# 136  weighted_specialization  weighted_specialization                  no
# 137  weighted_specialization  weighted_specialization               basic
# 148  weighted_specialization  weighted_specialization               basic
# 149  weighted_specialization  weighted_specialization               basic
# 150  weighted_specialization  weighted_specialization               basic
# 142  weighted_specialization  weighted_specialization               basic
# 143  weighted_specialization  weighted_specialization               basic
# 144  weighted_specialization  weighted_specialization               basic
# 145  weighted_specialization  weighted_specialization               basic
# 146  weighted_specialization  weighted_specialization               basic
# 147  weighted_specialization  weighted_specialization               basic
# 139  weighted_specialization  weighted_specialization               basic
# 140  weighted_specialization  weighted_specialization               basic
# 141  weighted_specialization  weighted_specialization               basic
# 138  weighted_specialization  weighted_specialization               basic
# 151  weighted_specialization  weighted_specialization                 all
# 162  weighted_specialization  weighted_specialization                 all
# 163  weighted_specialization  weighted_specialization                 all
# 164  weighted_specialization  weighted_specialization                 all
# 156  weighted_specialization  weighted_specialization                 all
# 157  weighted_specialization  weighted_specialization                 all
# 158  weighted_specialization  weighted_specialization                 all
# 159  weighted_specialization  weighted_specialization                 all
# 160  weighted_specialization  weighted_specialization                 all
# 161  weighted_specialization  weighted_specialization                 all
# 153  weighted_specialization  weighted_specialization                 all
# 154  weighted_specialization  weighted_specialization                 all
# 155  weighted_specialization  weighted_specialization                 all
# 152  weighted_specialization  weighted_specialization                 all
#
#     Filtered  Filter Mode n_duplicates F1 Score (avg)
# 0         No          N/A          N/A           75.3
# 1         No          N/A          N/A           75.3
# 2         No          N/A          N/A           75.3
# 15        No          N/A          N/A           74.7
# 16        No          N/A          N/A           72.5
# 17        No          N/A          N/A           33.8
# 30        No          N/A          N/A           74.7
# 31        No          N/A          N/A           73.2
# 32        No          N/A          N/A           33.8
# 45        No          N/A          N/A           75.3
# 46       Yes       unique            0           75.3
# 47        No          N/A          N/A           75.4
# 58       Yes  autoencoder            1           75.2
# 59       Yes  autoencoder            3           75.4
# 60       Yes  autoencoder            5           75.4
# 52       Yes   imputation            1           75.2
# 53       Yes   imputation            3           75.4
# 54       Yes   imputation            5           75.4
# 55       Yes          knn            1           75.2
# 56       Yes          knn            3           75.4
# 57       Yes          knn            5           75.4
# 49       Yes       random            1           75.4
# 50       Yes       random            3           75.4
# 51       Yes       random            5           75.4
# 48       Yes       unique            0           74.6
# 61        No          N/A          N/A           TODO
# 72       Yes  autoencoder            1           TODO
# 73       Yes  autoencoder            3           TODO
# 74       Yes  autoencoder            5           TODO
# 66       Yes   imputation            1           TODO
# 67       Yes   imputation            3           TODO
# 68       Yes   imputation            5           TODO
# 69       Yes          knn            1           TODO
# 70       Yes          knn            3           TODO
# 71       Yes          knn            5           TODO
# 63       Yes       random            1           TODO
# 64       Yes       random            3           TODO
# 65       Yes       random            5           TODO
# 62       Yes       unique            0           TODO
# 3         No          N/A          N/A           74.7
# 4         No          N/A          N/A           57.8
# 5         No          N/A          N/A           33.8
# 18        No          N/A          N/A           74.7
# 19        No          N/A          N/A           74.8
# 20        No          N/A          N/A           69.6
# 33        No          N/A          N/A           74.7
# 34        No          N/A          N/A           73.9
# 35        No          N/A          N/A           61.5
# 75        No          N/A          N/A           74.7
# 76       Yes       unique            0           74.7
# 77        No          N/A          N/A           61.4
# 88       Yes  autoencoder            1           63.3
# 89       Yes  autoencoder            3           61.6
# 90       Yes  autoencoder            5           61.6
# 82       Yes   imputation            1           53.6
# 83       Yes   imputation            3           61.6
# 84       Yes   imputation            5           61.6
# 85       Yes          knn            1           44.0
# 86       Yes          knn            3           61.6
# 87       Yes          knn            5           61.6
# 79       Yes       random            1           63.0
# 80       Yes       random            3           61.6
# 81       Yes       random            5           61.6
# 78       Yes       unique            0           51.8
# 91        No          N/A          N/A           TODO
# 102      Yes  autoencoder            1           TODO
# 103      Yes  autoencoder            3           TODO
# 104      Yes  autoencoder            5           TODO
# 96       Yes   imputation            1           TODO
# 97       Yes   imputation            3           TODO
# 98       Yes   imputation            5           TODO
# 99       Yes          knn            1           TODO
# 100      Yes          knn            3           TODO
# 101      Yes          knn            5           TODO
# 93       Yes       random            1           TODO
# 94       Yes       random            3           TODO
# 95       Yes       random            5           TODO
# 92       Yes       unique            0           TODO
# 6         No          N/A          N/A           74.7
# 7         No          N/A          N/A           57.8
# 8         No          N/A          N/A           33.8
# 21        No          N/A          N/A           74.7
# 22        No          N/A          N/A           73.8
# 23        No          N/A          N/A           64.2
# 36        No          N/A          N/A           74.7
# 37        No          N/A          N/A           74.6
# 38        No          N/A          N/A           69.1
# 105       No          N/A          N/A           74.7
# 106      Yes       unique            0           74.7
# 107       No          N/A          N/A           61.9
# 118      Yes  autoencoder            1           63.1
# 119      Yes  autoencoder            3           61.4
# 120      Yes  autoencoder            5           61.4
# 112      Yes   imputation            1           53.1
# 113      Yes   imputation            3           61.4
# 114      Yes   imputation            5           61.4
# 115      Yes          knn            1           43.8
# 116      Yes          knn            3           61.4
# 117      Yes          knn            5           61.4
# 109      Yes       random            1           62.3
# 110      Yes       random            3           61.4
# 111      Yes       random            5           61.4
# 108      Yes       unique            0           51.8
# 121       No          N/A          N/A           TODO
# 132      Yes  autoencoder            1           TODO
# 133      Yes  autoencoder            3           TODO
# 134      Yes  autoencoder            5           TODO
# 126      Yes   imputation            1           TODO
# 127      Yes   imputation            3           TODO
# 128      Yes   imputation            5           TODO
# 129      Yes          knn            1           TODO
# 130      Yes          knn            3           TODO
# 131      Yes          knn            5           TODO
# 123      Yes       random            1           TODO
# 124      Yes       random            3           TODO
# 125      Yes       random            5           TODO
# 122      Yes       unique            0           TODO
# 9         No          N/A          N/A           75.3
# 10        No          N/A          N/A           75.3
# 11        No          N/A          N/A           74.5
# 12        No          N/A          N/A           74.5
# 13        No          N/A          N/A           61.6
# 14        No          N/A          N/A           61.6
# 24        No          N/A          N/A           74.7
# 25        No          N/A          N/A           74.7
# 26        No          N/A          N/A           72.7
# 27        No          N/A          N/A           73.9
# 28        No          N/A          N/A           34.2
# 29        No          N/A          N/A           33.8
# 39        No          N/A          N/A           74.7
# 40        No          N/A          N/A           74.7
# 41        No          N/A          N/A           73.3
# 42        No          N/A          N/A           72.8
# 43        No          N/A          N/A           33.8
# 44        No          N/A          N/A           33.8
# 135       No          N/A          N/A           75.3
# 136      Yes       unique            0           75.3
# 137       No          N/A          N/A           75.3
# 148      Yes  autoencoder            1           74.9
# 149      Yes  autoencoder            3           75.3
# 150      Yes  autoencoder            5           75.3
# 142      Yes   imputation            1           75.2
# 143      Yes   imputation            3           75.3
# 144      Yes   imputation            5           75.3
# 145      Yes          knn            1           74.7
# 146      Yes          knn            3           75.3
# 147      Yes          knn            5           75.3
# 139      Yes       random            1           75.1
# 140      Yes       random            3           75.3
# 141      Yes       random            5           75.3
# 138      Yes       unique            0           74.3
# 151       No          N/A          N/A           TODO
# 162      Yes  autoencoder            1           TODO
# 163      Yes  autoencoder            3           TODO
# 164      Yes  autoencoder            5           TODO
# 156      Yes   imputation            1           TODO
# 157      Yes   imputation            3           TODO
# 158      Yes   imputation            5           TODO
# 159      Yes          knn            1           TODO
# 160      Yes          knn            3           TODO
# 161      Yes          knn            5           TODO
# 153      Yes       random            1           TODO
# 154      Yes       random            3           TODO
# 155      Yes       random            5           TODO
# 152      Yes       unique            0           TODO
