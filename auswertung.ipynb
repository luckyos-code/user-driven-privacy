# %%
# !module load dask/2022.1.0-foss-2021b
# !module load matplotlib/3.4.3-foss-2021b

# %%
# !pip install xgboost==2.0.3 h5py==3.11.0 seaborn==0.13.2 scikit-learn==1.2.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from itertools import product

# Reload the module for made changes
import importlib
import src
importlib.reload(src)

from src.ResultsIOHandler import compare_train_test_matrix_ext


# parameters
folder = "all-2025-06-11_09:58:20"
# folder = "all-2025-05-07_16:33:32"

datasets=[
    "adult",
    "diabetes"
]

train_methods=[
    "original"
    "no_preprocessing",
    "forced_generalization",
    "specialization",
    "weighted_specialization",
    "weighted_specialization_highest_confidence",
    
    "extended_weighted_specialization",
]

test_methods=[
    "original"
    "no_preprocessing",
    "forced_generalization",
    "specialization",
    "weighted_specialization",
    "weighted_specialization_highest_confidence",
    
    "extended_weighted_specialization",
]

for dataset in datasets:
    print(dataset)
    results_dir = os.path.join(os.getcwd(), "results", folder, dataset)
    plt = compare_train_test_matrix_ext(results_dir, dataset, train_methods, test_methods, anonymization_level=None)
# Out:
# adult
# diabetes
