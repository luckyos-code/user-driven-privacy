# %%
import pkgutil
import importlib
import src

def reload_src():
    for _, module_name, _ in pkgutil.walk_packages(src.__path__, src.__name__ + '.'):
        module = importlib.import_module(module_name)
        importlib.reload(module)

# %%
# Bulk-reload all src modules
# reload_src()

import os
# Import the dataset creation function
from src.DatasetCreation import create_dataset_versions

datasets = [
    'adult',
    'diabetes',
    # 'german_credit',
    # 'heart_disease',
    # 'student_performance',
    # 'bank_marketing'
]

# Sensible percentage combinations (must sum to 1.0)
combinations = [
    (0.33, 0.33, 0.34),
    (0, 0.5, 0.5),
]

# Iterate over datasets and combinations
for dataset in datasets:
    for original_pct, generalized_pct, missing_pct in combinations:
        print(f"Creating versions for {dataset} with original={original_pct}, generalized={generalized_pct}, missing={missing_pct}")
        create_dataset_versions(
            dataset=dataset,
            original_pct=original_pct,
            generalized_pct=generalized_pct,
            missing_pct=missing_pct,
            seed=42,
            #data_dir=os.path.join(os.getcwd(), 'data')
            data_dir="/Users/lucas/Downloads/data"
        )
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Bulk-reload all src modules
# ----> 2 reload_src()
#       4 import os
#       5 # Import the dataset creation function
#
# Cell In[1], line 7, in reload_src()
#       5 def reload_src():
#       6     for _, module_name, _ in pkgutil.walk_packages(src.__path__, src.__name__ + '.'):
# ----> 7         module = importlib.import_module(module_name)
#       8         importlib.reload(module)
#
# File ~/miniforge3/envs/user-driven-privacy/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/Library/CloudStorage/OneDrive-Personal/Dokumente/clara-backup/2025-07-01_16-59-25(cursor)/user-driven-privacy/src/DataLoader.py:3
#       1 import os
#       2 import pandas as pd
# ----> 3 import dask.dataframe as dd
#       4 from src.PreparingMethod import PreparingMethod
#       5 from src.DatasetManager import DatasetManager
#
# ModuleNotFoundError: No module named 'dask'
