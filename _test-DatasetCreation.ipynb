# %%
import pkgutil
import importlib
import src

def reload_src():
    for _, module_name, _ in pkgutil.walk_packages(src.__path__, src.__name__ + '.'):
        module = importlib.import_module(module_name)
        importlib.reload(module)

# %%
# Bulk-reload all src modules
reload_src()

import os
# Import the dataset creation function
from src.DatasetCreation import create_dataset_versions

datasets = [
    'adult',
    'diabetes',
    # 'german_credit',
    # 'heart_disease',
    # 'student_performance',
    # 'bank_marketing'
]

# Sensible percentage combinations (must sum to 1.0)
combinations = [
    (0.33, 0.33, 0.34),
    (0, 0.5, 0.5),
]

# Iterate over datasets and combinations
for dataset in datasets:
    for original_pct, generalized_pct, missing_pct in combinations:
        print(f"Creating versions for {dataset} with original={original_pct}, generalized={generalized_pct}, missing={missing_pct}")
        create_dataset_versions(
            dataset=dataset,
            original_pct=original_pct,
            generalized_pct=generalized_pct,
            missing_pct=missing_pct,
            seed=42,
            data_dir=os.path.join(os.getcwd(), 'data')
        )
# Out:
# Creating versions for adult with original=0.33, generalized=0.33, missing=0.34
# adult dataset already exists at /Users/lucas/Library/CloudStorage/OneDrive-Personal/Dokumente/clara-backup/2025-07-01_16-59-25(cursor)/user-driven-privacy/data/adult/adult.csv
# Split data for adult already exists, skipping.
# Generalized data for adult already exists, skipping.
# Forced generalization for adult already exists, skipping.
# Preprocessed data for specialization already exists, skipping.
# Preprocessed data for extended_weighted_specialization already exists, skipping.
# Data preparation workflow for adult finished.
# Creating versions for adult with original=0, generalized=0.5, missing=0.5
# adult dataset already exists at /Users/lucas/Library/CloudStorage/OneDrive-Personal/Dokumente/clara-backup/2025-07-01_16-59-25(cursor)/user-driven-privacy/data/adult/adult.csv
# Split data for adult already exists, skipping.
# Generalizing data for adult...
# Forced generalization for adult...
# Spalte age wurde vorverarbeitet
# Spalte capital-loss wurde vorverarbeitet
# Spalte capital-gain wurde vorverarbeitet
# Spalte education wurde vorverarbeitet
# Spalte fnlwgt wurde vorverarbeitet
# Spalte hours-per-week wurde vorverarbeitet
# Spalte marital-status wurde vorverarbeitet
# Spalte native-country wurde vorverarbeitet
# Spalte occupation wurde vorverarbeitet
# Spalte race wurde vorverarbeitet
# Spalte relationship wurde vorverarbeitet
# Spalte sex wurde vorverarbeitet
# Spalte workclass wurde vorverarbeitet
# Preprocessing: specialization for adult...
# Dataframe age wurde vorverarbeitet und gespeichert
# Dataframe capital-loss wurde vorverarbeitet und gespeichert
# Dataframe capital-gain wurde vorverarbeitet und gespeichert
# Dataframe education wurde vorverarbeitet und gespeichert
# Dataframe fnlwgt wurde vorverarbeitet und gespeichert
# Dataframe hours-per-week wurde vorverarbeitet und gespeichert
# Dataframe marital-status wurde vorverarbeitet und gespeichert
# Dataframe native-country wurde vorverarbeitet und gespeichert
# Dataframe occupation wurde vorverarbeitet und gespeichert
# Dataframe race wurde vorverarbeitet und gespeichert
# Dataframe relationship wurde vorverarbeitet und gespeichert
# Dataframe sex wurde vorverarbeitet und gespeichert
# Dataframe workclass wurde vorverarbeitet und gespeichert
# Preprocessing: extended_weighted_specialization for adult...
# Dataframe age wurde vorverarbeitet und gespeichert
# Dataframe capital-loss wurde vorverarbeitet und gespeichert
# Dataframe capital-gain wurde vorverarbeitet und gespeichert
# Dataframe education wurde vorverarbeitet und gespeichert
# Dataframe fnlwgt wurde vorverarbeitet und gespeichert
# Dataframe hours-per-week wurde vorverarbeitet und gespeichert
# Dataframe marital-status wurde vorverarbeitet und gespeichert
# Dataframe native-country wurde vorverarbeitet und gespeichert
# Dataframe occupation wurde vorverarbeitet und gespeichert
# Dataframe race wurde vorverarbeitet und gespeichert
# Dataframe relationship wurde vorverarbeitet und gespeichert
# Dataframe sex wurde vorverarbeitet und gespeichert
# Dataframe workclass wurde vorverarbeitet und gespeichert
# Data preparation workflow for adult finished.
# Creating versions for diabetes with original=0.33, generalized=0.33, missing=0.34
# diabetes dataset already exists at /Users/lucas/Library/CloudStorage/OneDrive-Personal/Dokumente/clara-backup/2025-07-01_16-59-25(cursor)/user-driven-privacy/data/diabetes/diabetes.csv
# Split data for diabetes already exists, skipping.
# Generalized data for diabetes already exists, skipping.
# Forced generalization for diabetes already exists, skipping.
# Preprocessed data for specialization already exists, skipping.
# Preprocessed data for extended_weighted_specialization already exists, skipping.
# Data preparation workflow for diabetes finished.
# Creating versions for diabetes with original=0, generalized=0.5, missing=0.5
# diabetes dataset already exists at /Users/lucas/Library/CloudStorage/OneDrive-Personal/Dokumente/clara-backup/2025-07-01_16-59-25(cursor)/user-driven-privacy/data/diabetes/diabetes.csv
# Split data for diabetes already exists, skipping.
# Generalizing data for diabetes...
# Forced generalization for diabetes...
# Spalte Age wurde vorverarbeitet
# Spalte PhysHlth wurde vorverarbeitet
# Spalte Sex wurde vorverarbeitet
# Spalte Smoker wurde vorverarbeitet
# Spalte Stroke wurde vorverarbeitet
# Spalte Veggies wurde vorverarbeitet
# Spalte CholCheck wurde vorverarbeitet
# Spalte DiffWalk wurde vorverarbeitet
# Spalte BMI wurde vorverarbeitet
# Spalte Education wurde vorverarbeitet
# Spalte AnyHealthcare wurde vorverarbeitet
# Spalte Fruits wurde vorverarbeitet
# Spalte GenHlth wurde vorverarbeitet
# Spalte HeartDiseaseorAttack wurde vorverarbeitet
# Spalte HighChol wurde vorverarbeitet
# Spalte HighBP wurde vorverarbeitet
# Spalte HvyAlcoholConsump wurde vorverarbeitet
# Spalte Income wurde vorverarbeitet
# Spalte MentHlth wurde vorverarbeitet
# Spalte NoDocbcCost wurde vorverarbeitet
# Spalte PhysActivity wurde vorverarbeitet
# Preprocessing: specialization for diabetes...
# Dataframe Age wurde vorverarbeitet und gespeichert
# Dataframe PhysHlth wurde vorverarbeitet und gespeichert
# Dataframe Sex wurde vorverarbeitet und gespeichert
# Dataframe Smoker wurde vorverarbeitet und gespeichert
# Dataframe Stroke wurde vorverarbeitet und gespeichert
# Dataframe Veggies wurde vorverarbeitet und gespeichert
# Dataframe CholCheck wurde vorverarbeitet und gespeichert
# Dataframe DiffWalk wurde vorverarbeitet und gespeichert
# Dataframe BMI wurde vorverarbeitet und gespeichert
# Dataframe Education wurde vorverarbeitet und gespeichert
# Dataframe AnyHealthcare wurde vorverarbeitet und gespeichert
# Dataframe Fruits wurde vorverarbeitet und gespeichert
# Dataframe GenHlth wurde vorverarbeitet und gespeichert
# Dataframe HeartDiseaseorAttack wurde vorverarbeitet und gespeichert
# Dataframe HighChol wurde vorverarbeitet und gespeichert
# Dataframe HighBP wurde vorverarbeitet und gespeichert
# Dataframe HvyAlcoholConsump wurde vorverarbeitet und gespeichert
# Dataframe Income wurde vorverarbeitet und gespeichert
# Dataframe MentHlth wurde vorverarbeitet und gespeichert
# Dataframe NoDocbcCost wurde vorverarbeitet und gespeichert
# Dataframe PhysActivity wurde vorverarbeitet und gespeichert
# Preprocessing: extended_weighted_specialization for diabetes...
# Dataframe Age wurde vorverarbeitet und gespeichert
# Dataframe PhysHlth wurde vorverarbeitet und gespeichert
# Dataframe Sex wurde vorverarbeitet und gespeichert
# Dataframe Smoker wurde vorverarbeitet und gespeichert
# Dataframe Stroke wurde vorverarbeitet und gespeichert
# Dataframe Veggies wurde vorverarbeitet und gespeichert
# Dataframe CholCheck wurde vorverarbeitet und gespeichert
# Dataframe DiffWalk wurde vorverarbeitet und gespeichert
# Dataframe BMI wurde vorverarbeitet und gespeichert
# Dataframe Education wurde vorverarbeitet und gespeichert
# Dataframe AnyHealthcare wurde vorverarbeitet und gespeichert
# Dataframe Fruits wurde vorverarbeitet und gespeichert
# Dataframe GenHlth wurde vorverarbeitet und gespeichert
# Dataframe HeartDiseaseorAttack wurde vorverarbeitet und gespeichert
# Dataframe HighChol wurde vorverarbeitet und gespeichert
# Dataframe HighBP wurde vorverarbeitet und gespeichert
# Dataframe HvyAlcoholConsump wurde vorverarbeitet und gespeichert
# Dataframe Income wurde vorverarbeitet und gespeichert
# Dataframe MentHlth wurde vorverarbeitet und gespeichert
# Dataframe NoDocbcCost wurde vorverarbeitet und gespeichert
# Dataframe PhysActivity wurde vorverarbeitet und gespeichert
# Data preparation workflow for diabetes finished.
